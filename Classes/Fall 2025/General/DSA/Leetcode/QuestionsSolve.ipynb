# %%
Finding maximum size square in a given building height in a grid.

# %%
LC using 2 pointer and array partitioning and a OOP question

# %%
Prefix string problem using a Trie data structure

# %%
Solve problems involving arrays, strings, dynamic programming, and graph algorithms.
Example: Design and implement a graph algorithm or solve a matrix-related problem.
